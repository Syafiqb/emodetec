# %%
pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.22.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (2.1.3)
# Requirement already satisfied: torch==2.7.0 in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (4.11.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (75.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch==2.7.0->torchvision) (2024.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.7.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch==2.7.0->torchvision) (2.1.3)
# Downloading torchvision-0.22.0-cp312-cp312-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: torchvision
# Successfully installed torchvision-0.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
path/to/train', transform=train_transform)
test_dataset = datasets.ImageFolder(root='path/to/test', transform=test_transform)

# Data Loader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Arsitektur CNN
class EmotionCNN(nn.Module):
    def __init__(self, num_classes=7):
        super(EmotionCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(128 * 6 * 6, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes))
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

model = EmotionCNN(num_classes=7).to(device)

# Loss function dan optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Pelatihan model
num_epochs = 20
best_accuracy = 0.0
train_losses, test_losses = [], []
train_accs, test_accs = [], []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    
    # Evaluasi
    model.eval()
    test_loss = 0.0
    test_correct = 0
    test_total = 0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            test_total += labels.size(0)
            test_correct += predicted.eq(labels).sum().item()
    
    test_loss /= len(test_loader)
    test_acc = 100. * test_correct / test_total
    test_losses.append(test_loss)
    test_accs.append(test_acc)
    
    # Save model terbaik
    if test_acc > best_accuracy:
        best_accuracy = test_acc
        torch.save(model.state_dict(), 'best_model.pth')
    
    print(f'Epoch [{epoch+1}/{num_epochs}] | '
          f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | '
          f'Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%')

# Visualisasi
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.legend()
plt.title('Loss vs Epochs')

plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train Accuracy')
plt.plot(test_accs, label='Test Accuracy')
plt.legend()
plt.title('Accuracy vs Epochs')
plt.show()import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Konfigurasi device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Transformasi data
train_transform = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

test_transform = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# Load dataset
train_dataset = datasets.ImageFolder(root='
# Out:
# Train directory: /Users/syafiqbasmallah/Documents/emotion recog/train
# Test directory: /Users/syafiqbasmallah/Documents/emotion recog/test
# Error loading dataset: [Errno 2] No such file or directory: '/Users/syafiqbasmallah/Documents/emotion recog/train'
# Pastikan:
# 1. Path sudah benar
# 2. Struktur folder memiliki subfolder untuk setiap kelas
# 3. Folder train/test berisi subfolder dengan nama kelas (angry, happy, dll)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 57
#      54     exit()
#      56 # Data Loader
# ---> 57 train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
#      58 test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
#
# NameError: name 'train_dataset' is not defined

# %%
url = "/kaggle/input/emotion-detection-fer"
plt.figure(figsize=(12,5))

num = 0
for i in os.listdir(url):
    continue
for j in os.listdir(os.path.join(url, i)):
    path = os.path.join(url,i,j)

    for k in os.listdir(path):
        img = cv2.imread(os.path.join(path, k))
        plt.subplot(2,4,num+1)
        plt.imshow(img, cmap='gray')
        plt.axis('off')

        num += 1
        break
plt.show()

print(img.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 plt.figure(figsize=(12,5))
#       4 num = 0
# ----> 5 for i in os.listdir(url):
#       6     continue
#       7 for j in os.listdir(os.path.join(url, i)):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/emotion-detection-fer'

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# Konfigurasi device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Transformasi data
train_transform = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

test_transform = transforms.Compose([
    transforms.Resize((48, 48)),
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

# Perbaikan path dataset - sesuaikan dengan struktur folder Anda
base_dir = os.path.expanduser('~/Documents/emotion recog/dataemo')  # Path ke folder utama
train_dir = os.path.join(base_dir, 'train')  # Path ke folder train
test_dir = os.path.join(base_dir, 'test')    # Path ke folder test

# Verifikasi path
print(f"Train directory: {train_dir}")
print(f"Test directory: {test_dir}")

# Load dataset dengan path yang benar
try:
    train_dataset = datasets.ImageFolder(root=train_dir, transform=train_transform)
    test_dataset = datasets.ImageFolder(root=test_dir, transform=test_transform)
    
    print(f"Jumlah kelas: {len(train_dataset.classes)}")
    print(f"Nama kelas: {train_dataset.classes}")
    print(f"Jumlah gambar training: {len(train_dataset)}")
    print(f"Jumlah gambar test: {len(test_dataset)}")
    
except Exception as e:
    print(f"Error loading dataset: {e}")
    print("Pastikan:")
    print("1. Path sudah benar")
    print("2. Struktur folder memiliki subfolder untuk setiap kelas")
    print("3. Folder train/test berisi subfolder dengan nama kelas (angry, happy, dll)")
    exit()

# Data Loader
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Arsitektur CNN
class EmotionCNN(nn.Module):
    def __init__(self, num_classes=7):
        super(EmotionCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2, 2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(128 * 6 * 6, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(256, num_classes))
    
    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

model = EmotionCNN(num_classes=7).to(device)

# Loss function dan optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Pelatihan model
num_epochs = 20
best_accuracy = 0.0
train_losses, test_losses = [], []
train_accs, test_accs = [], []

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_accs.append(train_acc)
    
    # Evaluasi
    model.eval()
    test_loss = 0.0
    test_correct = 0
    test_total = 0
    
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            test_loss += loss.item()
            _, predicted = outputs.max(1)
            test_total += labels.size(0)
            test_correct += predicted.eq(labels).sum().item()
    
    test_loss /= len(test_loader)
    test_acc = 100. * test_correct / test_total
    test_losses.append(test_loss)
    test_accs.append(test_acc)
    
    # Save model terbaik
    if test_acc > best_accuracy:
        best_accuracy = test_acc
        torch.save(model.state_dict(), 'best_model.pth')
    
    print(f'Epoch [{epoch+1}/{num_epochs}] | '
          f'Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | '
          f'Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.2f}%')

# Visualisasi
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(test_losses, label='Test Loss')
plt.legend()
plt.title('Loss vs Epochs')

plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Train Accuracy')
plt.plot(test_accs, label='Test Accuracy')
plt.legend()
plt.title('Accuracy vs Epochs')
plt.show()
# Out:
# Train directory: /Users/syafiqbasmallah/Documents/emotion recog/dataemo/train
# Test directory: /Users/syafiqbasmallah/Documents/emotion recog/dataemo/test
# Jumlah kelas: 7
# Nama kelas: ['angry', 'disgusted', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
# Jumlah gambar training: 28709
# Jumlah gambar test: 7178
# Epoch [1/20] | Train Loss: 1.7306 | Train Acc: 30.16% | Test Loss: 1.5449 | Test Acc: 43.97%
# Epoch [2/20] | Train Loss: 1.5615 | Train Acc: 38.52% | Test Loss: 1.4188 | Test Acc: 45.28%
# Epoch [3/20] | Train Loss: 1.4975 | Train Acc: 41.24% | Test Loss: 1.3675 | Test Acc: 47.28%
# Epoch [4/20] | Train Loss: 1.4533 | Train Acc: 43.13% | Test Loss: 1.3391 | Test Acc: 47.38%
# Epoch [5/20] | Train Loss: 1.4230 | Train Acc: 44.20% | Test Loss: 1.2716 | Test Acc: 50.85%
# Epoch [6/20] | Train Loss: 1.4100 | Train Acc: 44.78% | Test Loss: 1.2866 | Test Acc: 51.23%
# Epoch [7/20] | Train Loss: 1.3735 | Train Acc: 45.93% | Test Loss: 1.2381 | Test Acc: 52.69%
# Epoch [8/20] | Train Loss: 1.3671 | Train Acc: 46.79% | Test Loss: 1.2344 | Test Acc: 52.59%
# Epoch [9/20] | Train Loss: 1.3540 | Train Acc: 47.26% | Test Loss: 1.2196 | Test Acc: 53.22%
# Epoch [10/20] | Train Loss: 1.3385 | Train Acc: 47.90% | Test Loss: 1.2558 | Test Acc: 51.98%
# Epoch [11/20] | Train Loss: 1.3210 | Train Acc: 48.71% | Test Loss: 1.1963 | Test Acc: 55.00%
# Epoch [12/20] | Train Loss: 1.3145 | Train Acc: 48.83% | Test Loss: 1.1895 | Test Acc: 54.64%
# Epoch [13/20] | Train Loss: 1.3034 | Train Acc: 49.59% | Test Loss: 1.1694 | Test Acc: 55.99%
# Epoch [14/20] | Train Loss: 1.2924 | Train Acc: 49.86% | Test Loss: 1.1620 | Test Acc: 56.14%
# Epoch [15/20] | Train Loss: 1.2755 | Train Acc: 50.40% | Test Loss: 1.1738 | Test Acc: 55.56%
# Epoch [16/20] | Train Loss: 1.2749 | Train Acc: 50.53% | Test Loss: 1.1547 | Test Acc: 56.66%
# Epoch [17/20] | Train Loss: 1.2665 | Train Acc: 51.01% | Test Loss: 1.1425 | Test Acc: 56.70%
# Epoch [18/20] | Train Loss: 1.2540 | Train Acc: 51.30% | Test Loss: 1.1386 | Test Acc: 56.94%
# Epoch [19/20] | Train Loss: 1.2453 | Train Acc: 51.84% | Test Loss: 1.1313 | Test Acc: 57.12%
# Epoch [20/20] | Train Loss: 1.2386 | Train Acc: 51.92% | Test Loss: 1.1272 | Test Acc: 57.84%
